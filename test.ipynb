# %%
print("test 중입니다")
# Out:
# test 중입니다

# %%
# !git checkout feature-A
# Out:
# error: Your local changes to the following files would be overwritten by checkout:
# 	test.ipynb
# Please commit your changes or stash them before you switch branches.
# Aborting

# %%
# !git add .

# %%
# !git reset --soft HEAD~3

# %%
# !git commit -m "colab to github"
# Out:
# [master 88ebe20] colab to github
#  3 files changed, 705520 insertions(+), 1 deletion(-)
#  create mode 100644 5_20_TicTocStock.ipynb
#  create mode 100644 test.ipynb

# %%
# !git push origin feature-A
# Out:
# error: src refspec feature-A does not match any
# error: failed to push some refs to 'https://github.com/hiimagoodguy/tiktokstock.git'

# %%
# !git branch
# Out:
# * master

# %%
# !git checkout -b feature-A
# Out:
# Switched to a new branch 'feature-A'
